# %% [markdown]
# # Hello World
#
# Welcome to Forgebook! This is a simple introductory notebook demonstrating the basics.
#
# ## Getting Started
#
# This notebook shows you how to:
# - Write markdown cells
# - Execute Python code
# - Display outputs

# %%
# A simple Python example
print("Hello, Forgebook!")

# %% [markdown]
# ## Working with Data
#
# Let's do some basic calculations:

# %%
# Simple arithmetic
numbers = [1, 2, 3, 4, 5]
total = sum(numbers)
average = total / len(numbers)

print(f"Numbers: {numbers}")
print(f"Sum: {total}")
print(f"Average: {average}")

# %% [markdown]
# ## Next Steps
#
# Check out more notebooks in the cookbook to learn about:
# - AI model integrations
# - Data processing patterns
# - Best practices
